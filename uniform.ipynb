# %%
import numpy as np
import scipy
import seaborn as sns
import matplotlib.pyplot as plt

from laws.uniform_law import generate_uniform_law, uniform_probability
from general_stats import perform_chi2_test
from functools import partial

# %%
a = 0
b = 1
n = 1000

uniform_values = generate_uniform_law(a, b, n)

chi2, empirical_values, expected_values, bins = perform_chi2_test(uniform_values, partial(uniform_probability, a, b))
print(chi2)
# Out:
# (9.027802267974257, 9)
